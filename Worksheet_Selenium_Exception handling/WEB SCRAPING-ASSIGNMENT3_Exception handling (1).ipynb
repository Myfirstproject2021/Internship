# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')

# %%
url='https://www.amazon.com/'
driver.get(url)

# %%
search_ITEM=driver.find_element_by_id("twotabsearchtextbox")
a=input(str("Enter ITEM NAME: "))
search_ITEM.send_keys(a)
#selected for guitar
# Out:
# Enter ITEM NAME: guitar

# %%
Select_button=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')
Select_button.click()

# %%
urls=[]
start=0
end=3
for page in range(start, end):
    time.sleep(4)
    next_button=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    
    for i in driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]'):
        urls.append(i.get_attribute("href"))
    next_button=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
#class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"

# %%
len(urls)
# Out:
# 175

# %%
product_title=[]
product_prize=[]
product_details=[]

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        title=driver.find_element_by_xpath('//h1[@class="a-size-large a-spacing-none"]')
        product_title.append(title.text)
    except:
         product_title.append('-')

    try:
        prize=driver.find_element_by_xpath('//span[@class="a-price a-text-price a-size-medium apexPriceToPay"]')
        product_prize.append(prize.text)

    except:
        product_prize.append('-')
        
    try:
        details=driver.find_element_by_xpath('//td[@class="a-span9"]')
        product_details.append(details.text.split("/n"))
    except:
         product_details.append('-')

#search_prize=driver.find_elements_by_xpath('//div[@class="product-price"]')

# %%
#len(product_details)
#Lenght match for all the attributes

#product_details
Gitar_details=pd.DataFrame({})
Gitar_details['Product_Title']=product_title
Gitar_details['Product_Prize']=product_prize
Gitar_details['Product_details']=product_details
Gitar_details
# Out:
#                                          Product_Title Product_Prize  \
# 0    38" Wood Guitar With Case and Accessories for ...        $58.99
# 1    Moukey 38in Acoustic Guitar for Beginner Kid A...        $79.99
# 2    30" Wood Classical Guitar with Case and Access...        $49.99
# 3    J&Z Classical Acoustic Guitar for Beginners Pr...        $92.99
# 4    38" Wood Guitar With Case and Accessories for ...        $58.99
# ..                                                 ...           ...
# 170  Ibanez 6 String Solid-Body Electric Guitar, Ri...             -
# 171  Pyle Electric Guitar and Amp Kit - Full Size I...             -
# 172  Marley X Guild Guitars A-20 Acoustic Guitar wi...             -
# 173  Fretboard Geek - 8.5 x 11" Guitar Cheat Sheet ...        $14.99
# 174  Danchet A103 Acoustic Guitar Strings,Bronze,Me...         $5.89
#
#      Product_details
# 0                 []
# 1                 []
# 2                 []
# 3                 []
# 4                 []
# ...

# %% [markdown]
# #3 Quaestion-he search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
url='https://images.google.com'
driver.get(url)

# %%
url='https://images.google.com'
names= "fruits cars MachineLearning Guitar Cakes"

res =names.split() 
urls_img=[]
urls_img_all=[]
image=[]

for i in res:
    search_ITEM=driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
    search_ITEM.send_keys(i)
    search_ITEM=driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]').click()
    time.sleep(2)
    
    
        
    for image in driver.find_elements_by_xpath('//a[@class="VFACy kGQAp sMi44c lNHeqe WGvvNb"]'):
        source=image.get_attribute("src")
        if source is not None:
            if(source[0:4]=='http'):
                urls_img.append(source)
                    
                    
    for i in range(len(urls_img)):
        if i >= 10:
            break
        print("Downloading {0} of {1} images" .format(i, 10))
        response=request.get(urls_img[i])
        file = open(r"C:/Users/surendar.reddy/Documents/data Science projet_Data traine/fruits"+str(i)+".jpg", "wb")
        file.write(response.content)
       
    driver.get(url)
        
urls_img_all.append(urls_img)

# %%
 print("Downloading {0} of {1} images" .format(i, 10))

# %%
for i in range(len(urls_img)):
        if i >= 10:
            break
        print("Downloading {0} of {1} images" .format(i, 10))

# %%
#file = open(r"C:/Users/surendar.reddy/Documents/data Science projet_Data traine\fruits"+str(i)+".jpg", "wb")
#file.write(response.content)

# %% [markdown]
# #Q4
# python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(1)
url='http://www.flipkart.com'
driver.get(url)

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search.send_keys("smart phone")
search_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button.click()

# %%
product_title=[]
product_details=[]
search_smartphone=driver.find_elements_by_xpath('//div[@class="_4rR01T"]')
for i in search_smartphone:
    product_title.append(i.text.split('('))
    
search_smartphone_details=driver.find_elements_by_xpath('//ul[@class="_1xgFaf"]')
for i in search_smartphone_details:   
    try:
        product_details.append(i.text.split('\n'))           
    except:
         product_details.append('-')

# %%
df2=pd.DataFrame(product_title)
#len(df2)
len(df)
# Out:
# 24

# %%
df=pd.DataFrame(product_details)
Frames=[df2, df]
Product=pd.concat(Frames,join='inner', axis=1)

#Sunglasses=pd.concat(Frames, join='inner', axis=0)
Product.columns=['Product Name','Colour','Storage','Display','Camara','Battery','Processor','Warrantly']
Product
# Out:
#            Product Name                   Colour  \
# 0     realme Narzo 50i      Carbon Black, 32 GB)
# 1     realme Narzo 50i        Mint Green, 32 GB)
# 2     realme Narzo 50i      Carbon Black, 64 GB)
# 3   SAMSUNG Galaxy F12         Sea Green, 64 GB)
# 4     realme Narzo 50A       Oxygen Blue, 64 GB)
# 5     realme Narzo 50A      Oxygen Green, 64 GB)
# 6     realme Narzo 50A     Oxygen Green, 128 GB)
# 7     realme Narzo 50A      Oxygen Blue, 128 GB)
# 8     realme Narzo 50i        Mint Green, 64 GB)
# 9            realme 8i     Space Purple, 128 GB)
# 10      REDMI 9i Sport      Carbon Black, 64 GB)
# 11  SAMSUNG Galaxy F12   Celestial Black, 64 GB)
# 12            OPPO A12    Flowing Silver, 64 GB)
# 13            OPPO A12             Black, 32 GB)
# 14     realme C11 2021         Cool Grey, 32 GB)
# 15     realme C11 2021         Cool Blue, 32 GB)
# 16        realme C25_Y       Metal Grey, 128 GB)
# 17        realme C25_Y        Metal Grey, 64 GB)
# ...

# %%
import csv
# name of csv file  
filename = "SmartPhone_Details.csv"
fields=['Product Name','Colour','Storage','Display','Camara','Battery','Processor','Warrantly']
rows=Product
# writing to csv file  
with open(filename, 'w') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
          
    # writing the fields  
    csvwriter.writerow(fields)  
          
    # writing the data rows  
    csvwriter.writerows(rows)

# %% [markdown]
# #5Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='https://www.google.com/maps'
driver.get(url)

# %%
search_map=driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div/div[3]/div/input[1]')
search_map.send_keys("Hyerabad")
search_button=driver.find_element_by_xpath('//div[@class="xoLGzf-BIqFsb-haAclf"]').click()

# %%
String_strUrl =driver.current_url
a=String_strUrl.split('/')
GPS_=pd.DataFrame(a)
display(GPS_.iloc[6])
# Out:
# 0    @17.4128805,77.8488782,9z
# Name: 6, dtype: object

# %% [markdown]
# #6 Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='https://www.trak.in'
driver.get(url)

# %%
driver.find_element_by_xpath('//li[@class="bs-pretty-tabs-container menu-item-has-children menu-item better-anim-fade bsm-leave"]').click()

# %%
#Funding_deals=[]
driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').click()
#Funding_deals.append(i.get_attribute("href"))

# %%
FD=[]
for i in driver.find_elements_by_xpath('//tbody[@class="row-hover"]'):
    FD.append(i.text.split(' '))


#FD.append(i.get_attribute('textContent').split(' \n'))

# %%
FD_DF=pd.DataFrame(FD)
cols  = FD_DF.columns
FD_DF.drop(columns =cols[11:285],inplace=True)
FD_DF
FD_DF.columns=['S.No','Date','StartUp','Industry','Industry2','Subverticle','City/Location','Investorssname1','Investorssname2','Investment Type','AmountUSD']
FD_DF
# Out:
#    S.No        Date     StartUp      Industry        Industry2  Subverticle  \
# 0     1  01/04/2021      BYJU’S      Edu-tech           Online     tutoring
# 1     1  04/03/2021   DealShare    E-commerce           Online     shopping
# 2     1  11/02/2021    Doubtnut           Edu             Tech   E-Learning
# 3     1  15/01/2021       Digit     Insurance        Financial     Services
# 4     1  15/12/2020        Bira            91             Food          and
# 5     1  30/11/2020    Codingal       EduTech           Online       coding
# 6     1  28/10/2020       Nykaa    E-commerce          Beauty,     Fashion,
# 7     1  08/09/2020      Byju’s       EduTech           Online     Tutoring
# 8     1  15/08/2020      Practo    HealthTech           Health         care
# 9     1  15/07/2020    Flipkart    E-commerce       E-commerce    Bangalore
# 10    1  18/06/2020     Drishti  Technologies       Technology   Artificial
# ...

# %%
FD_DF.Date = pd.to_datetime(FD_DF.Date, format = '%d/%m/%Y')
from_ts = '01/04/2021'
to_ts = '1/01/2021'
FD_DF= FD_DF[ (FD_DF['Date'] > to_ts)]
FD_DF
# Out:
#   S.No       Date    StartUp    Industry  Industry2 Subverticle City/Location  \
# 0    1 2021-04-01     BYJU’S    Edu-tech     Online    tutoring     Bengaluru
# 1    1 2021-03-04  DealShare  E-commerce     Online    shopping      platform
# 2    1 2021-02-11   Doubtnut         Edu       Tech  E-Learning      Platform
# 3    1 2021-01-15      Digit   Insurance  Financial    Services     Insurance
#
#   Investorssname1 Investorssname2 Investment Type  AmountUSD
# 0         Innoven         Capital          Series          F
# 1         Jaipur,       Rajasthan         Innoven    Capital
# 2         Gurgaon             SIG         Global,    Sequoia
# 3        Services       Bengaluru             A91  Partners,

# %% [markdown]
# #7)Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='https://digit.in/'
driver.get(url)

# %%
from selenium.webdriver.common.keys import Keys

# %%
search_laptop_details=driver.find_element_by_xpath('//div[@class="search"]').click()
search_laptop=driver.find_element_by_id("globalPageSearchText")
search_laptop.send_keys("Gaming Laptops")
time.sleep(1)
search_laptop.send_keys(Keys.ENTER)

# %%
Laptop=[]
for i in driver.find_elements_by_xpath('//div[@class="searchPage"]/a'):
    Laptop.append(i.get_attribute("href"))
Laptop
# Out:
# ['https://www.digit.in/laptops/hp-envy-15-k006tx-price-4429.html',
#  'https://www.digit.in/laptops/asus-g53j-a-3d-gamer-s-delight-but-we-want-more-price-3465.html',
#  'https://www.digit.in/laptops/lenovo-ideapad-y570-price-2979.html',
#  'https://www.digit.in/laptops/asus-g750jx-cv069p-price-4426.html',
#  'https://www.digit.in/audio-video/asus-rog-cetra-price-213419.html',
#  'https://www.digit.in/laptops/hp-pavilion-g6-multimedia-and-gaming-on-a-budget-price-3088.html',
#  'https://www.digit.in/laptops/asus-rog-flow-x13-price-229735.html',
#  'https://www.digit.in/tvs/truvision-tx3271-price-69451.html',
#  'https://www.digit.in/laptops/asus-zephyrus-g15-ryzen-9-5900hs-2021-price-231905.html',
#  'https://www.digit.in/laptops/lenovo-g50-30-price-6793.html']

# %%
Laptop_specification=[]
Laptop_prize=[]
for i in Laptop:
    driver.get(i)
    time.sleep(2)
    try:
        title=driver.find_element_by_xpath('//div[@class="key_specifications  notspecs "]')
        Laptop_specification.append(title.text.split('\n'))                                                     
    except:
         product_title.append('-')
    try:
        prize=driver.find_element_by_xpath('//div[@class="price_sec"]')
        Laptop_prize.append(prize.text.split('₹'))
    except:
        product_prize.append('-')

# %%
df=pd.DataFrame(Laptop_specification)
df1=pd.DataFrame(Laptop_prize)
df1.columns=['Name','details']
df1[['First','Last','drop']] = df1.details.str.split('\n',expand=True)
# Out:
#                     0                   1                   2  \
# 0  Key Specifications                  OS                  NA
# 1  Key Specifications                  OS                  NA
# 2  Key Specifications                  OS  Windows 7 (64-Bit)
# 3  Key Specifications                  OS                  NA
# 4  Key Specifications       Playback Time                  NA
# 5  Key Specifications                  OS                  NA
# 6  Key Specifications                  OS      Windows 10 Pro
# 7  Key Specifications  Screen Size (Inch)                  32
# 8  Key Specifications                  OS     Windows 10 Home
# 9  Key Specifications                  OS                  NA
#
#                  3                    4          5  \
# 0          Display                   NA  Processor
# 1          Display                   NA  Processor
# 2          Display   15.6" (1366 X 768)  Processor
# 3          Display                   NA  Processor
# ...

# %%
Frames=[df1, df]
Gaming_Laptops=pd.concat(Frames,join='inner', axis=1)
Gaming_Laptops.columns=['Name','drop','Prize','drop','drop','drop', 'drop','OS', 'drop','Display','drop','Processor','drop','Memeory',]
Gaming_Laptops.drop('drop', inplace=True, axis=1)
Gaming_Laptops
# Out:
#                                                 Name               Prize  \
# 0                 HP Envy 15-k006tx Price in India:               80,510
# 1  ASUS G53J - A 3D gamer's delight but we want m...             112,499
# 2               Lenovo IdeaPad Y570 Price in India:               49,900
# 3                Asus G750JX-CV069P Price in India:    149,999 (onwards)
# 4                    ASUS ROG Cetra Price in India:                7,699
# 5  HP Pavilion g6 - Multimedia and gaming on a bu...              45,000
# 6                 ASUS ROG Flow x13 Price in India:    154,990 (onwards)
# 7                   Truvison TX3271 Price in India:               23,490
# 8  ASUS Zephyrus G15 Ryzen 9 5900HS (2021) Price ...   137,990 (onwards)
# 9                     Lenovo G50-30 Price in India:     25,694 (onwards)
#
#                    OS              Display  \
# 0                  NA                   NA
# 1                  NA                   NA
# ...

# %% [markdown]
# #8 Scape Billarian from www.forbes.com.

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='http://www.forbes.com.'
driver.get(url)

# %%
#button[@class="icon--search"]

search_billarian=driver.find_element_by_xpath('//button[@class="icon--search"]').click()
search_billarian=driver.find_element_by_xpath('//input[@class="search-modal__input"]')
search_billarian.send_keys("billionaires in 2020")
search_billarian.send_keys(Keys.ENTER)

# %%
search_billarian_item=driver.find_element_by_xpath('/html/body/div[1]/main/div[1]/div[1]/div[4]/div/article[1]/div[1]/h3/a').get_attribute("href")

# %%
i=search_billarian_item
driver.get(i)

# %%
billarian=[]
Networth=[]
Citizen=[]
SOURCE_OF_WEALTH=[]
#for i in driver.find_elements_by_xpath('//h2[@class="subhead-embed color-accent bg-base font-accent"]'):
    #billarian.append(i.text)
#billarian

for i in driver.find_elements_by_xpath('//strong[contains(text(),"Net worth")]'):
    Networth.append(i.text)
for i in driver.find_elements_by_xpath('//strong[contains(text(),"Citizenship")]'):
    Citizen.append(i.text)
for i in driver.find_elements_by_xpath('//strong[contains(text(),"Source of wealth")]'):
    SOURCE_OF_WEALTH.append(i.text)
#for i in driver.find_elements_by_xpath('//strong[contains(text(),"BILLION")]'):
    #Residence.append(i.text)
#Residence
SOURCE_OF_WEALTH
# Out:
# ['Source of wealth: vaping devices',
#  'Source of wealth: biotech',
#  'Source of wealth: automotive sensors',
#  'Source of wealth: online games',
#  'Source of wealth: E-commerce ',
#  'Source of wealth: DoorDash',
#  'Source of wealth: education technology ',
#  'Source of wealth: online payments',
#  'Source of wealth: electric car startup',
#  'Source of wealth: trading app Robinhood Financial']

# %%
df=pd.DataFrame({})
Billarian = [ ('Chen Zhiping') ,('Stephane Bancel') ,('Austin Russell') ,('Dmitry Bukhman') ,('Matt Moulding') ,('Tony Xu') ,('Byju Raveendran and Divya Gokulnath'),('Jared Isaacmanv'), ('Geeta Gupta-Fisker and Henrik Fisker'),('Vlad Tenev')]
df['Billarian']=Billarian
df['Networth']=Networth
df['Citizen']=Citizen
df['SOURCE_OF_WEALTH']=SOURCE_OF_WEALTH
df
# Out:
#                               Billarian                      Networth  \
# 0                          Chen Zhiping      Net worth: $15.3 billion
# 1                       Stephane Bancel       Net worth: $3.6 billion
# 2                        Austin Russell       Net worth: $3.3 billion
# 3                        Dmitry Bukhman       Net worth: $3.1 billion
# 4                         Matt Moulding         Net worth: $3 billion
# 5                               Tony Xu       Net worth: $2.7 billion
# 6   Byju Raveendran and Divya Gokulnath      Net worth: $2.5 billion
# 7                       Jared Isaacmanv       Net worth: $2.1 billion
# 8  Geeta Gupta-Fisker and Henrik Fisker  Net worth: $1.2 billion each
# 9                            Vlad Tenev         Net worth: $1 billion
#
#                       Citizen  \
# 0          Citizenship: China
# 1         Citizenship: France
# 2           Citizenship: U.S.
# 3         Citizenship: Russia
# 4           Citizenship: U.K.
# ...

# %% [markdown]
# Person_Name=[]
# name= driver.find_elements_by_xpath("//div[@class='personName']//div")
#
# for i in name:
#     Person_Name.append(i.text)
# Person_Name

# %% [markdown]
# #9 Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='https://www.youtube.com'
driver.get(url)
time.sleep(10)

# %%
search_vedio=driver.find_element_by_xpath('//input[@class="ytd-searchbox"]')
search_vedio.send_keys("butta bomma song")
search_vedio.send_keys(Keys.ENTER)

# %%
vedio=driver.find_element_by_xpath('//a[@class="yt-simple-endpoint style-scope ytd-video-renderer"]').get_attribute("href")
driver.get(vedio)
time.sleep(4)

# %%
driver.execute_script("window.scrollTo(0, 3240)")

# %%
comments=[]
comments_time=[]
start=0
end=7
for page in range(start, end):
    driver.execute_script("window.scrollTo(0, 3240)")
    time.sleep(4)
    for i in driver.find_elements_by_xpath('//yt-formatted-string[@class="published-time-text above-comment style-scope ytd-comment-renderer"]'):
        try:
            comments_time.append(i.text)
        except:
             comments_time.append('-')
    
    for i in driver.find_elements_by_id("content-text"):
        try:
            comments.append(i.text)
        except:
             comments.append('-')

# %%
len(comments)
# Out:
# 560

# %%
df=pd.DataFrame({})
df['Comment']=comments
df['time']=comments_time
df
# Out:
#                                                Comment                 time
# 0           2:07 What a magical voice of Armaan Malik          2 months ago
# 1                               Armaan Malik's Voice ️          2 weeks ago
# 2                              Can feel soul of music           12 days ago
# 3    I couldn't understand the language because I'm...           6 days ago
# 4    This masterpiece movie is coming in theatres a...  7 days ago (edited)
# ..                                                 ...                  ...
# 555  Coming in Hindi From 26 Jan 2022 In cinema. He...           7 days ago
# 556                 No song can beat this, next level             1 day ago
# 557  Allu Arjun expression,style & dance + pooja he...           2 days ago
# 558  Allu Arjun is not a South Indian star.. He is ...           1 year ago
# 559  Now.. finally this masterpiece going to releas...           7 days ago
#
# [560 rows x 2 columns]

# %% [markdown]
# #10 available Hostels from https://www.hostelworld.com/ in
# “London” location.

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
url='https://www.hostelworld.com/'
driver.get(url)

# %%
search_hostel=driver.find_element_by_id("location-text-input-field")
search_hostel.send_keys("London")

# %%
search_hostel=driver.find_element_by_id("search-input-field")
search_hostel.send_keys("London")

# %%
search=driver.find_element_by_xpath('//div[@class="label"]').click()

# %%
dropdown = driver.find_element_by_xpath('//i[@class="core-icon icon-core-calendar"]').click()
#selected date manually 26th jan; 29 Jan

# %%
letgo_button=driver.find_element_by_xpath('//div[@class="search-button"]').click()

# %% [markdown]
# hotels=[]
# for i in driver.find_elements_by_xpath('//h2[@class="title title-6"]/a'):
#     hotels.append(i.get_attribute("href"))
# hotels

# %% [markdown]
# Faciliy=[]
# Staff=[]
# cleaniness=[]
# Review_Overall=[]
# hotel=[]
# Distance=[]
# Rating=[]
# Rating_Number=[]
#
# for i in hotels:
#     driver.get(i)
#     time.sleep(2)
#     try:
#         driver.find_elements_by_xpath('//div[@class="score orange big"][1]')
#         Review_Overall.append(i.text)
#     except:
#         Review_Overall.append('-')
#     try:
#         driver.find_elements_by_xpath('//div[@class="keyword"]')
#         Faciliy.append(i.text)
#     except:
#         Faciliy.append('-')
#     try:
#         driver.find_elements_by_xpath('//div[@class="staff"]')
#         Staff.append(i.text)
#     except:
#         Staff.append('-')
#     try:
#         driver.find_elements_by_xpath('//div[@class="cleanliness"]')
#         cleaniness.append(i.text)
#     except:
#         cleaniness.append('-')
#
#     try:
#         driver.find_elements_by_xpath('//div[@class="title-2"]')
#         hotel.append(i.text)
#     except:
#         hotel.append('-')
#
#     try:
#         driver.find_elements_by_xpath('//buton[@class="property-address"]')
#         Distance.append(i.text)
#     except:
#         Distance.append('-')
#
#     try:
#         driver.find_elements_by_xpath('//div[@class="score orange big"][1]')
#         Rating.append(i.text)
#     except:
#         Rating.append('-')
#
#     try:
#         driver.find_elements_by_xpath('//div[@class="reviews"]')
#         Rating_Number.append(i.text)
#     except:
#         Rating_Number.append('-')

# %% [markdown]
# piates=[]
# Prize=[]
#
#
#
#     try:
#         driver.find_elements_by_xpath('//p[contains(text(),"Privates")]')
#         piates.append(i.text)
#     except:
#         piates.append('-')
#
#
#     try:
#         driver.find_elements_by_xpath('//p[contains(text(),"Dorms")]')
#         Prize.append(i.text)
#     except:
#         Prize.append('-')

# %%
Faciliy=[]
Staff=[]
cleaniness=[]
Review_Overall=[]
hotel=[]
Distance=[]
Rating=[]
Rating_Number=[]
piates=[]
Prize=[]

for i in driver.find_elements_by_xpath('//h2[@class="title title-6"]'):
    hotel.append(i.text)
for i in driver.find_elements_by_xpath('//span[@class="description"]'):
    Distance.append(i.text) 
for i in driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]'):
    Rating.append(i.text)
for i in driver.find_elements_by_xpath('//div[@class="keyword"]'):
    try:
        Review_Overall.append(i.text)
    except:
        Review_Overall.append('-')

for i in driver.find_elements_by_xpath('//div[@class="reviews"]'):
    try:
        Rating_Number.append(i.text)
    except:
        Rating_Number.append('-')

for i in driver.find_elements_by_xpath('//p[contains(text(),"Privates")]'):
    try:
        piates.append(i.text)
    except:
        piates.append('-')  
        
for i in driver.find_elements_by_xpath('//div[@class="location"]'):
    try:
        Faciliy.append(i.text)
    except:
        Faciliy.append('-')

for i in driver.find_elements_by_xpath('//div[@class="staff"]'):
    try:
        Staff.append(i.text)
    except:
        Staff.append('-')
for i in driver.find_elements_by_xpath('//div[@class="cleanliness"]'):
    try:
        cleaniness.append(i.text)
    except:
        cleaniness.append('-')
        Staff.append('-')
for i in driver.find_elements_by_xpath('//p[contains(text(),"Dorms")]'):
        Prize.append(i.text)

# %%
print('Hotel-',len(hotel))
print('Distance-',len(Distance))
print('Rating-',len(Rating))
print('Review_Overall-',len(Review_Overall))
print('Rating_Number-',len(Rating_Number))
print('piates-',len(piates))
print('Faciliy-',len(Faciliy))
print('Staff-',len(Staff))
print('cleaniness-',len(cleaniness))
print('Prize-',len(Prize))
# Out:
# Hotel- 30
# Distance- 30
# Rating- 30
# Review_Overall- 31
# Rating_Number- 30
# piates- 30
# Faciliy- 29
# Staff- 29
# cleaniness- 27
# Prize- 30

# %%
# Not able to scape equall no. of text in all the headings
#Also tried with url, all blanks are scaped.
#Even afetr trying with URL as above cell, Not able to get

df=pd.DataFrame({})
df['Hotel']=hotel
df['Distance']=Distance
df['Faciliy']=Faciliy
df['Staff']=Staff
df['cleaniness']=cleaniness
df['Hostel Rating']=Rating
df['Review_Overall']=Review_Overall
df['Rating_Number']=Rating_Number
df['piates']=piates
df['Prize']=Prize
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SUREND~1.RED\AppData\Local\Temp/ipykernel_12396/777830206.py in <module>
#       5 df['Hotel']=hotel
#       6 df['Distance']=Distance
# ----> 7 df['Faciliy']=Faciliy
#       8 df['Staff']=Staff
#       9 df['cleaniness']=cleaniness
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
# ...
