# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
search_details=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]')

table_details=[]
for i in search_details:
    table_details.append(i.text.split('\n'))
# Out:
# [['Top 30 most-viewed YouTube videos[2]',
#   'No. Video name Uploader Views (billions) Upload date Note',
#   '1. "Baby Shark Dance"[3] Pinkfong Baby Shark - Kids\' Songs & Stories 10.21 June 17, 2016 [B]',
#   '2. "Despacito"[6] Luis Fonsi 7.75 January 12, 2017 [C]',
#   '3. "Johny Johny Yes Papa"[12] LooLoo Kids 6.17 October 8, 2016 [D]',
#   '4. "Shape of You"[13] Ed Sheeran 5.62 January 30, 2017 [E]',
#   '5. "See You Again"[15] Wiz Khalifa 5.42 April 6, 2015 [F]',
#   '6. "Bath Song"[20] Cocomelon – Nursery Rhymes 4.99 May 2, 2018 [G]',
#   '7. "Learning Colors – Colorful Eggs on a Farm"[21] Miroshka TV 4.56 February 27, 2018 [H]',
#   '8. "Masha and the Bear – Recipe for Disaster"[22] Get Movies 4.48 January 31, 2012 [I]',
#   '9. "Phonics Song with Two Words"[23] ChuChu TV 4.47 March 6, 2014 [J]',
#   '10. "Uptown Funk"[24] Mark Ronson 4.46 November 19, 2014 [K]',
#   '11. "Gangnam Style"[25] Psy 4.34 July 15, 2012 [L]',
# ...

# %%
Details=pd.DataFrame(table_details)
Details=pd.DataFrame.transpose(Details)
Details.drop([1], inplace=True, axis=1)
Details.loc[:31]
# Out:
#                                                     0
# 0                Top 30 most-viewed YouTube videos[2]
# 1   No. Video name Uploader Views (billions) Uploa...
# 2   1. "Baby Shark Dance"[3] Pinkfong Baby Shark -...
# 3   2. "Despacito"[6] Luis Fonsi 7.75 January 12, ...
# 4   3. "Johny Johny Yes Papa"[12] LooLoo Kids 6.17...
# 5   4. "Shape of You"[13] Ed Sheeran 5.62 January ...
# 6   5. "See You Again"[15] Wiz Khalifa 5.42 April ...
# 7   6. "Bath Song"[20] Cocomelon – Nursery Rhymes ...
# 8   7. "Learning Colors – Colorful Eggs on a Farm"...
# 9   8. "Masha and the Bear – Recipe for Disaster"[...
# 10  9. "Phonics Song with Two Words"[23] ChuChu TV...
# 11  10. "Uptown Funk"[24] Mark Ronson 4.46 Novembe...
# 12  11. "Gangnam Style"[25] Psy 4.34 July 15, 2012...
# 13  12. "Dame Tu Cosita"[30] El Chombo 3.85 April ...
# 14  13. "Wheels on the Bus"[31] Cocomelon – Nurser...
# 15     14. "Sugar"[32] Maroon 5 3.64 January 14, 2015
# ...

# %% [markdown]
# ## 2 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://www.bcci.tv/.'
driver.get(url)

# %%
button_international=driver.find_element_by_xpath('//button[@class="navbar-toggler menu-btn menu-icon"]').click()

# %%
select_internation=driver.find_element_by_xpath('//li[@class="nav-item ml-0"]').click()

# %%
select_match=driver.find_element_by_xpath('//a[@class="match-center-btn ng-scope"]').get_attribute("href")

# %%
driver.get(select_match)

# %%
match_title=[]

title=driver.find_element_by_xpath('//div[@class="tournament--name ng-binding ng-scope"]')
match_title.append(title.text.split(','))

date=driver.find_element_by_xpath('//div[@class="matchDate alignC ng-binding ng-scope"]')
match_title.append(date.text.split(','))

place=driver.find_element_by_xpath('//span[@class="matGround ng-binding"]')
match_title.append(place.text.split(','))

place_=driver.find_element_by_xpath('//span[@class="matPlace ng-binding ng-scope"]')
match_title.append(place_.text.split(','))

VS_=driver.find_element_by_xpath('//span[@class="tName ng-binding ng-scope"]')
match_title.append(VS_.text.split(','))

VS__=driver.find_element_by_xpath('//*[@id="scoreBox"]/div[1]/div/div[2]/div[2]/span[2]')
match_title.append(VS__.text)

# %%
match_title
# Out:
# [['WEST INDIES TOUR OF INDIA T20 SERIES 2022'],
#  ['20 FEB 2022'],
#  ['EDEN GARDENS'],
#  ['KOLKATA'],
#  ['INDIA'],
#  'WEST INDIES']

# %% [markdown]
# ## 3 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://www.guru99.com/'
driver.get(url)
time.sleep(2)

# %%
from selenium.webdriver.common.keys import Keys

# %%
button_search=driver.find_element_by_xpath('//input[@class="gsc-input"]')
button_search.send_keys("Selenium Exception Handling")
time.sleep(1)
button_search.send_keys(Keys.ENTER)

# %%
select_website=driver.find_element_by_xpath('//a[@class="gs-title"]').get_attribute("href")
driver.get(select_website)

# %%
search_excep=driver.find_elements_by_xpath('//table[@class="table table-striped"]')
exceps=[]
for i in search_excep:
    exceps.append(i.text.split('\n'))

# %%
df_exceps=pd.DataFrame(exceps)
df_exceps=pd.DataFrame.transpose(df_exceps)

# %%
headers = df_exceps.iloc[0]
df_exceps.columns = [headers]  
df_exceps.drop(index=0, inplace=True) # drop the first row

# %%
df_exceps
# Out:
# 0                          Exception name Description
# 1   ElementNotVisibleException This type of Seleni...
# 2   ElementNotSelectableException This Selenium ex...
# 3   NoSuchElementException This Exception occurs i...
# 4   NoSuchFrameException This Exception occurs if ...
# 5   NoAlertPresentException This Exception occurs ...
# 6   NoSuchWindowException This Exception occurs if...
# 7   StaleElementReferenceException This Selenium e...
# 8   SessionNotFoundException The WebDriver is acti...
# 9   TimeoutException Thrown when there is not enou...
# 10  WebDriverException This Exception takes place ...
# 11  ConnectionClosedException This type of Excepti...
# 12  ElementClickInterceptedException The command m...
# 13  ElementNotInteractableException This Selenium ...
# 14  ErrorInResponseException This happens while in...
# 15  ErrorHandler.UnknownServerException Exception ...
# 16  ImeActivationFailedException This expectation ...
# ...

# %%
df[['code','name_of_code']] = df["code"].str.split(" ", 1, expand=True)

# %% [markdown]
# ## 4 question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='http://statisticstimes.com/'
driver.get(url)
time.sleep(2)

# %%
select_economy=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
select_india=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').get_attribute("href")

# %%
driver.get(select_india)

# %%
select_GDP=driver.find_element_by_xpath('//a[contains(text(),"GDP of Indian states")]').get_attribute("href")

# %%
driver.get(select_GDP)

# %% [markdown]
# '//p[contains(text(),"Privates")]'

# %%
GDP_No=[]
for i in driver.find_elements_by_xpath('//td[@class="data1"]'):
    GDP_No.append(i.text.split(','))
    
    
GDP_State=[]
for i in driver.find_elements_by_xpath('//td[@class="name"]'):
    GDP_State.append(i.text.split(','))
    
GDP_value=[]
for i in driver.find_elements_by_xpath('//td[@class="data sorting_1"]'):
    GDP_value.append(i.text)

        
GDP_share=[]
for i in driver.find_elements_by_xpath('//td[contains(text(),"%")]'):
    GDP_share.append(i.text)

# %%
GDP=pd.DataFrame({})
GDP['No']=GDP_No
GDP['State']=GDP_State
GDP['GDP']=GDP_value
GDP['Share']=GDP_share
GDP
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SUREND~1.RED\AppData\Local\Temp/ipykernel_8808/3319626658.py in <module>
#       3 #GDP['State']=GDP_State
#       4 GDP['GDP']=GDP_value
# ----> 5 GDP['Share']=GDP_share
#       6 GDP
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# ...

# %%
    
len(GDP_value)
# Out:
# 66

# %%
len(GDP_No)
# Out:
# 68

# %% [markdown]
# ## Question 5

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://github.com/'
driver.get(url)
time.sleep(2)

# %%
select_github=driver.find_element_by_xpath('//button[@class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit"]').click()

# %%
select_github=driver.find_element_by_xpath('//summary[contains(text(),"Explore")]').click()

# %%
select_github=driver.find_element_by_xpath('//a[contains(text(),"Trending")]').click()

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]


for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        title=driver.find_element_by_xpath('//h1[@class="a-size-large a-spacing-none"]')
        product_title.append(title.text)
    except:
         product_title.append('-')

# %%
urls=[]
for i in driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]/a'):
        urls.append(i.get_attribute("href"))

# %%
urls
# Out:
# ['https://github.com/Anduin2017/HowToCook',
#  'https://github.com/NVlabs/instant-ngp',
#  'https://github.com/yt-dlp/yt-dlp',
#  'https://github.com/coding-horror/basic-computer-games',
#  'https://github.com/odin-lang/Odin',
#  'https://github.com/emilk/egui',
#  'https://github.com/martinvonz/jj',
#  'https://github.com/adrianhajdin/project_professional_portfolio',
#  'https://github.com/lwthiker/curl-impersonate',
#  'https://github.com/danistefanovic/build-your-own-x',
#  'https://github.com/doocs/advanced-java',
#  'https://github.com/BlueWallet/BlueWallet',
#  'https://github.com/supabase/supabase',
#  'https://github.com/freeCodeCamp/freeCodeCamp',
#  'https://github.com/cryptotwinsbr/spacecrypto-bot',
#  'https://github.com/harmonoid/harmonoid',
#  'https://github.com/withfig/autocomplete',
#  'https://github.com/myugan/awesome-docker-security',
#  'https://github.com/BuilderIO/qwik',
#  'https://github.com/danielbeach/data-engineering-practice',
# ...

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        title=driver.find_element_by_xpath('//a[@class="url fn"]')
        Repository_title.append(title.text)
    except:
         Repository_title.append('-')

    try:
        count=driver.find_element_by_xpath('//div[@class="mt-3"]')
        Contributors_count.append(count.text)

    except:
        Contributors_count.append('-')
        
    try:
        desc=driver.find_element_by_xpath('//p[@class="f4 my-3"]')
        Repository_description.append(desc.text)

    except:
        Repository_description.append('-')
    try:
        lang=driver.find_element_by_xpath('//li[@class="d-inline"]')
        Language_used.append(lang.text)

    except:
        Language_used.append('-')

# %%
df=pd.DataFrame({})
df['Repository_title']=Repository_title
df['Repository_description']=Repository_description
df['Contributors_count']=Contributors_count
df['Language_used']=Language_used
df.columns=['Repository_title','Repository_description','Contributors_count','Language_used']

# %%
df
# Out:
#    Repository_title                             Repository_description  \
# 0        Anduin2017                                       程序员在家做饭方法指南。
# 1            NVlabs  Instant neural graphics primitives: lightning ...
# 2            yt-dlp  A youtube-dl fork with additional features and...
# 3     coding-horror  An updated version of the classic "Basic Compu...
# 4         odin-lang                          Odin Programming Language
# 5             emilk  egui: an easy-to-use immediate mode GUI in Rus...
# 6        martinvonz  A Git-compatible DVCS that is both simple and ...
# 7      adrianhajdin  This is a code repository for the correspondin...
# 8          lwthiker  curl-impersonate: A special compilation of cur...
# 9    danistefanovic          🤓 Build your own (insert technology here)
# 10            doocs  😮 Core Interview Questions & Answers For Exper...
# 11       BlueWallet  Bitcoin thin client for iOS & Android. Built w...
# ...

# %% [markdown]
# ## 6 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https:/www.billboard.com'
driver.get(url)
time.sleep(2)

# %%
select_charts=driver.find_element_by_xpath('//a[contains(text(),"Charts")]').get_attribute("href")

# %%
driver.get(select_charts)

# %%
select_hot100=driver.find_element_by_xpath('//a[@class="c-label__link lrv-u-color-brand-primary u-color-black@mobile-max a-font-primary-bold lrv-u-font-size-32 u-whitespace-nowrap@tablet"]').get_attribute("href")

# %%
driver.get(select_hot100)

# %%
vedio_Name=[]
for i in driver.find_elements_by_xpath('//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]'):
    vedio_Name.append(i.text)

# %%
vedio_artist=[]
for i in driver.find_elements_by_xpath('//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]'):
    vedio_artist.append(i.text)

# %%
vedio_rating=[]
for i in driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]/span'):
    vedio_rating.append(i.text)

# %%
odd_rating = []
even_rating = []
for i in range(0, len(vedio_rating)):
    if i % 2:
        even_rating.append(vedio_rating[i])
    else :
        odd_rating.append(vedio_rating[i])
 
res = odd_rating + even_rating
 
# print result

# %%
del odd_rating[0]
del even_rating[0]

# %%
peak_rating=[]
for i in driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]'):
    peak_rating.append(i.text)

# %%
odd_peak_rating = []
even_peak_rating = []
for i in range(0, len(peak_rating)):
    if i % 2:
        even_peak_rating.append(peak_rating[i])
    else :
        odd_peak_rating.append(peak_rating[i])
 
res = odd_peak_rating + even_peak_rating

# %%
del even_peak_rating[0]

# %%
df=pd.DataFrame({})
df['vedio_Name']=vedio_Name
df['vedio_artist']=vedio_artist

df['Last_WeeK']=odd_rating
df['PeakRating']=even_peak_rating
df['Weeks_charts']=even_rating

# %%
df
# Out:
#                vedio_Name                      vedio_artist Last_WeeK  \
# 0   Do We Have A Problem?            Nicki Minaj X Lil Baby         -
# 1              Easy On Me                             Adele         2
# 2              Heat Waves                     Glass Animals         3
# 3                    Stay     The Kid LAROI & Justin Bieber         4
# 4           Super Gremlin                       Kodak Black         5
# ..                    ...                               ...       ...
# 94                   Iffy                       Chris Brown        87
# 95          When I'm Gone               Alesso / Katy Perry         -
# 96             Fair Trade      Drake Featuring Travis Scott        90
# 97          Megan's Piano               Megan Thee Stallion        97
# 98        Moth To A Flame  Swedish House Mafia & The Weeknd         -
#
#    PeakRating Weeks_charts
# 0           2            1
# 1           1           18
# 2           3           56
# ...

# %% [markdown]
# ## 7 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://www.naukri.com/'
driver.get(url)
time.sleep(2)

# %%
search_ITEM=driver.find_element_by_xpath('//input[@class="suggestor-input "]')
search_ITEM.send_keys("Data science")

# %%
from selenium.webdriver.common.keys import Keys
search_ITEM.send_keys(Keys.ENTER)

# %%
search_recruters=driver.find_element_by_xpath('//a[@title="Search Recruiters"]').get_attribute("href")

# %%
driver.get(search_recruters)

# %%
urls=[]
for i in driver.find_elements_by_xpath('//div[@class="recImg mid_pImg_Silht"]/a'):
        urls.append(i.get_attribute("href"))

# %%
Recruiters_Name=[]
Recruiters_Desig=[]
Recruiters_Company=[]
Recruiters_skill=[]
Recruiters_location=[]

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        Name=driver.find_element_by_xpath('//h1[@class="fl ellipsis wLimit hd"]')
        Recruiters_Name.append(Name.text)
    except:
         Recruiters_Name.append('-')

    try:
        Designation=driver.find_element_by_xpath('//div[@class="ellipsis"]')
        Recruiters_Desig.append(Designation.text)

    except:
        Recruiters_Desig.append('-')
        
    try:
        Company=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[4]/a')
        Recruiters_Company.append(Company.text)

    except:
        Recruiters_Company.append('-')
        
    try:
        location=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[5]/a')
        Recruiters_location.append(location.text)

    except:
        Recruiters_location.append('-')
        
    try:
        skill=driver.find_element_by_xpath('//*[@id="skillInfo"]/p[1]')
        Recruiters_skill.append(skill.text)

    except:
        Recruiters_skill.append('-')

# %%
df=pd.DataFrame({})
df['Recruiters_Name']=Recruiters_Name
df['Recruiters_Desig']=Recruiters_Desig
df['Recruiters_Company']=Recruiters_Company
df['Recruiters_location']=Recruiters_location
df['Recruiters_skill']=Recruiters_skill
df
# Out:
#              Recruiters_Name                   Recruiters_Desig  \
# 0             Santhosh Kumar  Associate Manager Human Resources
# 1                 Surendra R                  Company Recruiter
# 2                    Sanghvi                  Company Recruiter
# 3               Gauri Bhosle                    Human Resources
# 4           Rohit Khandelwal                  Company Recruiter
# 5                Neha Pandey                  Company Recruiter
# 6                Vinita Raut                  Company Recruiter
# 7              Reena Dwivedi             Human Resource Manager
# 8            Team - HRM Info                Recruitment Manager
# 9                     Snehal                       HR cum Admin
# 10            Anamika Sharma            Human Resources Manager
# 11  MARSIAN Technologies LLP                         Company HR
# 12          MD SALATIN RIZVI                Recruitment Manager
# 13         QAD India Pvt Ltd                          Recruiter
# ...

# %% [markdown]
# ## 8 question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(2)

# %%
search_book=driver.find_elements_by_xpath('//table[@class="in-article sortable"]')
book=[]
for i in search_book:
    book.append(i.text.split('\n'))

# %%
book
# Out:
# [['Top 100 best selling books of all time',
#   'UK sales only. Click heading to sort table. Download this data',
#   'Rank',
#   'Title',
#   'Author',
#   'Volume Sales',
#   'Publisher',
#   'Genre',
#   'SOURCE: NIELSEN BOOK SCAN',
#   '1 Da Vinci Code,The Brown, Dan 5,094,805 Transworld Crime, Thriller & Adventure',
#   "2 Harry Potter and the Deathly Hallows Rowling, J.K. 4,475,152 Bloomsbury Children's Fiction",
#   "3 Harry Potter and the Philosopher's Stone Rowling, J.K. 4,200,654 Bloomsbury Children's Fiction",
#   "4 Harry Potter and the Order of the Phoenix Rowling, J.K. 4,179,479 Bloomsbury Children's Fiction",
#   '5 Fifty Shades of Grey James, E. L. 3,758,936 Random House Romance & Sagas',
#   "6 Harry Potter and the Goblet of Fire Rowling, J.K. 3,583,215 Bloomsbury Children's Fiction",
#   "7 Harry Potter and the Chamber of Secrets Rowling, J.K. 3,484,047 Bloomsbury Children's Fiction",
# ...

# %%
df=pd.DataFrame(book)

# %%
df=pd.DataFrame.transpose(df)

# %%
df=df.iloc[9:]

# %%
df
# Out:
#                                                      0
# 9    1 Da Vinci Code,The Brown, Dan 5,094,805 Trans...
# 10   2 Harry Potter and the Deathly Hallows Rowling...
# 11   3 Harry Potter and the Philosopher's Stone Row...
# 12   4 Harry Potter and the Order of the Phoenix Ro...
# 13   5 Fifty Shades of Grey James, E. L. 3,758,936 ...
# ..                                                 ...
# 104  96 Ghost,The Harris, Robert 807,311 Random Hou...
# 105  97 Happy Days with the Naked Chef Oliver, Jami...
# 106  98 Hunger Games,The:Hunger Games Trilogy Colli...
# 107  99 Lost Boy,The:A Foster Child's Search for th...
# 108  100 Jamie's Ministry of Food:Anyone Can Learn ...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## 9 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://www.imdb.com/list/ls095964455'
driver.get(url)
time.sleep(2)

# %%
urls=[]
for i in driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a'):
        urls.append(i.get_attribute("href"))

# %%
Movie_Name=[]
Movie_Genre=[]
Movie_rating=[]
Movie_votes=[]

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        Name=driver.find_element_by_xpath('//div[@class="TitleBlock__TitleContainer-sc-1nlhx7j-1 jxsVNt"]')
        Movie_Name.append(Name.text.split('\n'))
    except:
        Movie_Name.append('-')
        
    try:
        Genre=driver.find_element_by_xpath('//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[7]/div[2]/ul[2]/li[2]/div')
        Movie_Genre.append(Genre.text)

    except:
        Movie_Genre.append('-')
               
    try:
        Rating=driver.find_element_by_xpath('//span[@class="AggregateRatingButton__RatingScore-sc-1ll29m0-1 iTLWoV"]')
        Movie_rating.append(Rating.text)

    except:
        Movie_rating.append('-')
        
    try:
        votes=driver.find_element_by_xpath('//div[@class="AggregateRatingButton__TotalRatingAmount-sc-1ll29m0-3 jkCVKJ"]')
        Movie_votes.append(votes.text)

    except:
        Movie_votes.append('-')

# %%
df=pd.DataFrame({})
#df['Movie_Name,Series,Year, Series2, Series2']=Movie_Name
df['Movie_Genre']=Movie_Genre
df['Movie_rating']=Movie_rating
df['Movie_votes']=Movie_votes
df
# Out:
#                                 Movie_Genre Movie_rating Movie_votes
# 0                                         -          9.2          2M
# 1   DramaFantasyHorrorMysterySci-FiThriller          8.7        966K
# 2                                         -          8.1        932K
# 3                                         -          7.5        279K
# 4                        DramaMysterySci-Fi          7.6        239K
# ..                                      ...          ...         ...
# 95                             DramaFantasy          7.5         48K
# 96        AdventureComedyDramaFamilyMystery          7.8         59K
# 97                CrimeDramaMysteryThriller          8.1        186K
# 98    ComedyCrimeDramaHorrorMysteryThriller          7.1         39K
# 99               DramaHorrorMysteryThriller          8.6        222K
#
# [100 rows x 3 columns]

# %%
df1=pd.DataFrame(Movie_Name)
df1.columns=['Name','series','Year','Series2','Runtime','Runtime']
Full_Details=pd.concat([df1,df],axis=1)
Full_Details
# Out:
#                               Name                  series       Year  \
# 0                  Game of Thrones               TV Series  2011–2019
# 1                  Stranger Things               TV Series      2016–
# 2                 The Walking Dead               TV Series  2010–2022
# 3                   13 Reasons Why               TV Series  2017–2020
# 4                          The 100               TV Series  2014–2020
# ..                             ...                     ...        ...
# 95                           Reign               TV Series  2013–2017
# 96  A Series of Unfortunate Events               TV Series  2017–2019
# 97                  Criminal Minds               TV Series  2005–2020
# 98           Scream: The TV Series  Original title: Scream  TV Series
# 99      The Haunting of Hill House          TV Mini Series       2018
#
#       Series2 Runtime Runtime                              Movie_Genre  \
# ...

# %% [markdown]
# ## 10 Question

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\Web Scaping_Worksheet-2\chromedriver_win32\chromedriver.exe')
time.sleep(2)
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(2)

# %%
select_alldateset=driver.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/span[2]/a').click()

# %%
driver.get(select_alldateset)

# %%
urls=[]
for i in driver.find_elements_by_xpath('//p[@class="normal"]/b/a'):
        urls.append(i.get_attribute("href"))

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        Name=driver.find_element_by_xpath('//span[@class="heading"]')
        Dataset_name.append(Name.text)
    except:
        Dataset_name.append('-')
        
    try:
        type=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[1]/td[2]/p')
        Data_type.append(type.text)
    except:
        Data_type.append('-')
    
    try:
        task=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[3]/td[2]/p')
        Task.append(task.text)
    except:
        Task.append('-')
        
        
    try:
        attribute=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[2]/p')
        Attribute_type.append(attribute.text)

    except:
        Attribute_type.append('-')
               
    try:
        instances=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[1]/td[4]/p')
        No_of_instances.append(instances.text)

    except:
        No_of_instances.append('-')
        
    try:
        no_attributes=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[4]/p')
        No_of_attribute.append(no_attributes.text)

    except:
        No_of_attribute.append('-')
        
    try:
        year=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[6]/p')
        Year.append(year.text)

    except:
        Year.append('-')

# %%
p=[]
for i in driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[6]/p'):
    p.append(i.text)
p
# Out:
# ['1995-12-01']

# %%
df=pd.DataFrame({})

df['Dataset_name']=Dataset_name
df['Data_type']=Data_type
df['Task']=Task
df['Attribute_type']=Attribute_type
df['No_of_instances']=No_of_instances
df['No_of_attribute']=No_of_attribute
df['Year']=Year

df
# Out:
#                                           Dataset_name  \
# 0                                     Abalone Data Set
# 1                                       Adult Data Set
# 2                                   Annealing Data Set
# 3                Anonymous Microsoft Web Data Data Set
# 4                                  Arrhythmia Data Set
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618             Turkish Music Emotion Dataset Data Set
# 619             Maternal Health Risk Data Set Data Set
# 620                 Room Occupancy Estimation Data Set
# 621  Image Recognition Task Execution Times in Mobi...
#
#                                Data_type                 Task  \
# 0                           Multivariate       Classification
# 1                           Multivariate       Classification
# 2                           Multivariate       Classification
# ...
