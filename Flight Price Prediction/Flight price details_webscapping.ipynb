# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time

# Buitiful soup if needed
from bs4 import BeautifulSoup
#Importing requests
import requests
# importing regex
import re

#importing exceptions error
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException


from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=26%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-flights&unqvaldesktop=1206718911299"
driver.get(url)

# %%
clear_ITEM1=driver.find_element_by_id("origin_0").clear()
time.sleep(2)
clear_ITEM2=driver.find_element_by_id("destination_0").clear()
time.sleep(2)

start_ITEM=driver.find_element_by_id("origin_0")
end_ITEM=driver.find_element_by_id("destination_0")
a=input(str("Enter ITEM start NAME: "))
b=input(str("Enter ITEM End NAME: "))
start_ITEM.send_keys(a)
time.sleep(10)
end_ITEM.send_keys(b)

time.sleep(5)
select_flight=driver.find_element_by_xpath('//button[@class="fs-14 btn-submit cursor-pointer bold"]').click()


#ng-class="modifySearch.$valid== false || submitted ||specialFareError.error?'disabled   ':''"
#class="fs-16 bold ng-touched ng-dirty ng-valid-parse ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required"
# Out:
# Enter ITEM start NAME: Hyderabad
# Enter ITEM End NAME: Mumbai

# %%
HYD_MUM_26apr = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_26apr.append(i.text.split('\n'))
HYD_MUM_26apr
# Out:
# [['DEALBook this flight and get upto Rs. 1,500 OFF. Use code: FLYNOW',
#   'Vistara',
#   'UK-878',
#   '12:55',
#   'Hyderabad',
#   '14:30',
#   'Mumbai',
#   '1h 35m',
#   'Non Stop',
#   '1 left at5,528',
#   'Book Now',
#   'Flight Details',
#   'Free Meal',
#   'Emissions: 169 Kg CO2',
#   'eCash 250'],
#  ['DEALBook this flight and get upto Rs. 1,900 OFF. Use code: FLYNOW',
#   'IndiGo',
#   '6E-5316',
#   '21:45',
#   'Hyderabad',
#   '23:10',
#   'Mumbai',
#   '1h 25m',
#   'Non Stop',
#   '4 left at6,105',
#   'View Fares',
#   'Flight Details',
#   'eCash 250'],
#  ['DEALBook this flight and get upto Rs. 1,500 OFF. Use code: FLYNOW',
#   'Vistara',
#   'UK-876',
#   '21:35',
#   'Hyderabad',
#   '23:00',
#   'Mumbai',
#   '1h 25m',
#   'Non Stop',
#   '1 left at6,263',
#   'Book Now',
#   'Flight Details',
#   'Free Meal',
#   'Emissions: 169 Kg CO2',
#   'eCash 250'],
#  ['DEALBook this flight and get upto Rs. 1,900 OFF. Use code: FLYNOW',
#   'IndiGo',
#   '6E-6699',
# ...

# %%
df1_HYD_MUM_26apr=pd.DataFrame(HYD_MUM_26apr)
df1_HYD_MUM_26apr
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 5   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 6   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 9   DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 10  DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 11  DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 12  DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# ...

# %%
writer=pd.ExcelWriter("df1_HYD_MUM_26apr.xlsx")
df1_HYD_MUM_26apr.to_excel(writer,"26apr", header=True, index= False)
writer.save()

# %% [markdown]
# ## Manuall selected 10 days later flight(repeated till next 4 month' )
# 6 may
# #16-may
# #26 May
# #6 June
# 16 June
# 26 june
# 6 Jul
# 16 july
# 26 July
# 6 aug
# 16 aug
# 26 aug
# 6 sep

# %%
HYD_MUM_6May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_6May.append(i.text.split('\n'))
df2_HYD_MUM_6May=pd.DataFrame(HYD_MUM_6May)
df2_HYD_MUM_6May
writer=pd.ExcelWriter("df2_HYD_MUM_6May.xlsx")
df2_HYD_MUM_6May.to_excel(writer,"26apr", header=True, index= False)
writer.save()

# %%
HYD_MUM_16May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_16May.append(i.text.split('\n'))
df_HYD_MUM_16May=pd.DataFrame(HYD_MUM_16May)

#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_16May.xlsx")
df_HYD_MUM_16May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_MUM_16May
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...   Go First
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 10  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 11  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 12  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# ...

# %%
HYD_MUM_26May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_26May.append(i.text.split('\n'))
df_HYD_MUM_26May=pd.DataFrame(HYD_MUM_26May)

#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_26May.xlsx")
df_HYD_MUM_26May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_MUM_26May
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,500 OF...   Go First
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 10  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 11  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 12  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# ...

# %%
HYD_MUM_6June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_6June.append(i.text.split('\n'))
df_HYD_MUM_6June=pd.DataFrame(HYD_MUM_6June)


#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_6June.xlsx")
df_HYD_MUM_6June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_MUM_6June
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,500 OF...   Go First
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 10  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 11  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 12  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# ...

# %%
HYD_MUM_16June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_16June.append(i.text.split('\n'))
df_HYD_MUM_16June=pd.DataFrame(HYD_MUM_16June)


#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_16June.xlsx")
df_HYD_MUM_16June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_MUM_16June
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,500 OF...   Go First
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 10  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 11  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 12  DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# ...

# %%
HYD_MUM_26June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_26June.append(i.text.split('\n'))
df_HYD_MUM_26June=pd.DataFrame(HYD_MUM_26June)

#display the dataframe
df_HYD_MUM_26June
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,500 OF...   Go First
# 9   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_26June.xlsx")
df_HYD_MUM_26June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_6July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_6July.append(i.text.split('\n'))
df_HYD_MUM_6July=pd.DataFrame(HYD_MUM_6July)

#display the dataframe
df_HYD_MUM_6July
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_6July.xlsx")
df_HYD_MUM_6July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_16July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_16July.append(i.text.split('\n'))
df_HYD_MUM_16July=pd.DataFrame(HYD_MUM_16July)


#display the dataframe
df_HYD_MUM_16July
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_16July.xlsx")
df_HYD_MUM_16July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_26July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_26July.append(i.text.split('\n'))
df_HYD_MUM_26July=pd.DataFrame(HYD_MUM_26July)


#display the dataframe
df_HYD_MUM_26July
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_26July.xlsx")
df_HYD_MUM_26July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_6Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_6Aug.append(i.text.split('\n'))
df_HYD_MUM_6Aug=pd.DataFrame(HYD_MUM_6Aug)



#display the dataframe
df_HYD_MUM_6Aug
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 1   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 2   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 10  DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_6Aug.xlsx")
df_HYD_MUM_6Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_16Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_16Aug.append(i.text.split('\n'))
df_HYD_MUM_16Aug=pd.DataFrame(HYD_MUM_16Aug)



#display the dataframe
df_HYD_MUM_16Aug
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 1   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 4   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 7   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 8   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 9   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_16Aug.xlsx")
df_HYD_MUM_16Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_26Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_26Aug.append(i.text.split('\n'))
df_HYD_MUM_26Aug=pd.DataFrame(HYD_MUM_26Aug)


#display the dataframe
df_HYD_MUM_26Aug
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 1   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 2   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 5   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 6   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 7   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 8   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 9   DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 10  DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 11  DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# 12  DEALBook this flight and get upto Rs. 1,800 OF...   Air Asia
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_26Aug.xlsx")
df_HYD_MUM_26Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %%
HYD_MUM_6sep = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     HYD_MUM_6sep.append(i.text.split('\n'))
df_HYD_MUM_6sep=pd.DataFrame(HYD_MUM_6sep)

#display the dataframe
df_HYD_MUM_6sep
# Out:
#                                                    0          1   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 1   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 2   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 3   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 4   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 5   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 6   DEALBook this flight and get upto Rs. 1,500 OF...    Vistara
# 7   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 8   DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 9   DEALBook this flight and get upto Rs. 1,350 OF...  Air India
# 10  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 11  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# 12  DEALBook this flight and get upto Rs. 1,900 OF...     IndiGo
# ...

# %%
#writing in Excel
writer=pd.ExcelWriter("df_HYD_MUM_6sep.xlsx")
df_HYD_MUM_6sep.to_excel(writer,"sheet", header=True, index= False)
writer.save()

# %% [markdown]
# ## trying to collect major trasport cities
# ## Delhi -Mumbai

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)

url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=26%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-flights&unqvaldesktop=1206718911299"
driver.get(url)

# %%
clear_ITEM1=driver.find_element_by_id("origin_0").clear()
time.sleep(2)
clear_ITEM2=driver.find_element_by_id("destination_0").clear()
time.sleep(2)

start_ITEM=driver.find_element_by_id("origin_0")
end_ITEM=driver.find_element_by_id("destination_0")
a=input(str("Enter ITEM start NAME: "))
b=input(str("Enter ITEM End NAME: "))
start_ITEM.send_keys(a)
time.sleep(10)
end_ITEM.send_keys(b)

time.sleep(5)
select_flight=driver.find_element_by_xpath('//button[@class="fs-14 btn-submit cursor-pointer bold"]').click()
# Out:
# Enter ITEM start NAME: Delhi
# Enter ITEM End NAME: Mumbai

# %%
Del_MUM_26apr = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_26apr.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_26apr=pd.DataFrame(Del_MUM_26apr)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_26apr.xlsx")
df_Del_MUM_26apr.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_26apr
# Out:
#                                                    0        1           2   \
# 0   DEALBook this flight and get upto Rs. 1,900 OF...   IndiGo     6E-5318
# 1   DEALBook this flight and get upto Rs. 1,900 OF...   IndiGo     6E-2519
# 2   DEALBook this flight and get upto Rs. 1,900 OF...   IndiGo     6E-5306
# 3   DEALBook this flight and get upto Rs. 1,900 OF...   IndiGo      6E-864
# 4   DEALBook this flight and get upto Rs. 1,900 OF...   IndiGo     6E-6261
# ..                                                ...      ...         ...
# 86  DEALBook this flight and get upto Rs. 1,500 OF...  Vistara  UK-809/854
# 87  DEALBook this flight and get upto Rs. 1,500 OF...  Vistara  UK-809/846
# 88  DEALBook this flight and get upto Rs. 1,500 OF...  Vistara  UK-813/846
# 89  DEALBook this flight and get upto Rs. 1,500 OF...  Vistara  UK-809/852
# 90  DEALBook this flight and get upto Rs. 1,500 OF...  Vistara  UK-813/852
#
#        3          4      5        6       7         8         9   \
# ...

# %%
Del_MUM_6May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_6May.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_6May=pd.DataFrame(Del_MUM_6May)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_6MAy.xlsx")
df_Del_MUM_6May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_6May
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,800 OF...  Air Asia       I5-753
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2138
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5342
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5318
# ..                                                 ...       ...          ...
# 172  DEALBook this flight and get upto Rs. 1,500 OF...   Vistara   UK-819/866
# 173  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8373/945
# 174  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/398
# 175  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
# 176  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/168
#
# ...

# %%
Del_MUM_16May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_16May.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_16May=pd.DataFrame(Del_MUM_16May)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_16MAy.xlsx")
df_Del_MUM_16May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_16May
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,800 OF...  Air Asia       I5-753
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2138
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5342
# ..                                                 ...       ...          ...
# 167  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
# 168  DEALBook this flight and get upto Rs. 1,500 OF...   Vistara   UK-643/648
# 169  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/168
# 170  DEALBook this flight and get upto Rs. 1,500 OF...   Vistara   UK-611/648
# 171  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
#
# ...

# %%
for _ in range(10000):
    driver.execute_script("window.scrollBy(0,10000)")
time.sleep(2)

Del_MUM_26May = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_26May.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_26May=pd.DataFrame(Del_MUM_26May)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_26MAy.xlsx")
df_Del_MUM_26May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_26May
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2138
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5342
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2009
# ..                                                 ...       ...          ...
# 165  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
# 166  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
# 167  DEALBook this flight and get upto Rs. 1,500 OF...  Go First  G8-1010/287
# 168  DEALBook this flight and get upto Rs. 1,500 OF...  Go First   G8-213/287
# 169  DEALBook this flight and get upto Rs. 1,500 OF...  Go First   G8-191/287
#
# ...

# %%
for _ in range(10000):
    driver.execute_script("window.scrollBy(0,10000)")
time.sleep(2)

Del_MUM_6June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_6June.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_6June=pd.DataFrame(Del_MUM_6June)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_6June.xlsx")
df_Del_MUM_6June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_6June
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,800 OF...  Air Asia       I5-753
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2138
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5342
# ..                                                 ...       ...          ...
# 162  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8373/945
# 163  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8963/945
# 164  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/951
# 165  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
# 166  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
#
# ...

# %%
#for _ in range(100000):
#    driver.execute_script("window.scrollBy(0,100000)")
#time.sleep(2)

Del_MUM_16June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_16June.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_16June=pd.DataFrame(Del_MUM_16June)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_16June.xlsx")
df_Del_MUM_16June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_16June
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,800 OF...  Air Asia       I5-753
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2138
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5342
# ..                                                 ...       ...          ...
# 157  DEALBook this flight and get upto Rs. 1,500 OF...  Go First   G8-190/386
# 158  DEALBook this flight and get upto Rs. 1,500 OF...  Go First  G8-191/3185
# 159  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/168
# 160  DEALBook this flight and get upto Rs. 1,500 OF...  Go First   G8-191/287
# 161  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
#
# ...

# %%
Del_MUM_26June = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_26June.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_26June=pd.DataFrame(Del_MUM_26June)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_26June.xlsx")
df_Del_MUM_26June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_26June
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,500 OF...   Vistara       UK-981
# 1    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2009
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2112
# ..                                                 ...       ...          ...
# 164  DEALBook this flight and get upto Rs. 1,500 OF...   Vistara   UK-829/876
# 165  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8187/168
# 166  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8963/945
# 167  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/951
# 168  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
#
# ...

# %%
Del_MUM_6July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_6July.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_6July=pd.DataFrame(Del_MUM_6July)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_6July.xlsx")
df_Del_MUM_6July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_6July
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,500 OF...   Vistara       UK-975
# 1    DEALBook this flight and get upto Rs. 1,500 OF...   Vistara       UK-981
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2009
# ..                                                 ...       ...          ...
# 170  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/398
# 171  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/168
# 172  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/951
# 173  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
# 174  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-751/114
#
# ...

# %%
Del_MUM_16July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_16July.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_16July=pd.DataFrame(Del_MUM_16July)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_16July.xlsx")
df_Del_MUM_16July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_16July
# Out:
#                                                     0         1            2   \
# 0    DEALBook this flight and get upto Rs. 1,500 OF...   Vistara       UK-975
# 1    DEALBook this flight and get upto Rs. 1,500 OF...   Vistara       UK-981
# 2    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-5023
# 3    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-6814
# 4    DEALBook this flight and get upto Rs. 1,900 OF...    IndiGo      6E-2009
# ..                                                 ...       ...          ...
# 173  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet  SG-8903/168
# 174  DEALBook this flight and get upto Rs. 1,500 OF...  Go First   G8-191/287
# 175  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/951
# 176  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-473/945
# 177  DEALBook this flight and get upto Rs. 1,500 OF...  SpiceJet   SG-751/114
#
# ...

# %%
Del_MUM_26July = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_26July.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_26July=pd.DataFrame(Del_MUM_26July)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_26July.xlsx")
df_Del_MUM_26July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_26July
# Out:
#             0           1      2          3      4        5       6   \
# 0      Vistara      UK-975  06:00  New Delhi  08:00   Mumbai  2h 00m
# 1      Vistara      UK-981  21:55  New Delhi  23:55   Mumbai  2h 00m
# 2       IndiGo     6E-5023  06:30  New Delhi  08:35   Mumbai  2h 05m
# 3       IndiGo     6E-6814  07:20  New Delhi  09:25   Mumbai  2h 05m
# 4       IndiGo     6E-5318  17:00  New Delhi  19:05   Mumbai  2h 05m
# ..         ...         ...    ...        ...    ...      ...     ...
# 172  Air India  AI-407/732  13:45  New Delhi  12:05  + 1 day  Mumbai
# 173    Vistara  UK-643/648  14:10  New Delhi  19:00   Mumbai  4h 50m
# 174   SpiceJet  SG-473/951  06:25  New Delhi  13:35   Mumbai  7h 10m
# 175   SpiceJet  SG-473/945  06:25  New Delhi  16:10   Mumbai  9h 45m
# 176   SpiceJet  SG-751/114  11:30  New Delhi  18:10   Mumbai  6h 40m
#
#            7       8           9               10                    11  \
# ...

# %%
Del_MUM_6Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_6Aug.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_6Aug=pd.DataFrame(Del_MUM_6Aug)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_6Aug.xlsx")
df_Del_MUM_6Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_6Aug
# Out:
#            0            1      2          3      4       5        6   \
# 0      IndiGo      6E-5023  06:30  New Delhi  08:35  Mumbai   2h 05m
# 1      IndiGo      6E-6814  07:20  New Delhi  09:25  Mumbai   2h 05m
# 2      IndiGo      6E-5318  17:00  New Delhi  19:05  Mumbai   2h 05m
# 3      IndiGo      6E-2112  05:30  New Delhi  07:40  Mumbai   2h 10m
# 4    Go First       G8-530  06:50  New Delhi  08:55  Mumbai   2h 05m
# ..        ...          ...    ...        ...    ...     ...      ...
# 173  SpiceJet  SG-8903/398  06:30  New Delhi  14:30  Mumbai   8h 00m
# 174  SpiceJet  SG-8903/168  06:30  New Delhi  19:25  Mumbai  12h 55m
# 175  SpiceJet   SG-473/945  06:25  New Delhi  16:10  Mumbai   9h 45m
# 176  SpiceJet   SG-473/951  06:25  New Delhi  13:35  Mumbai   7h 10m
# 177  SpiceJet   SG-751/114  11:30  New Delhi  18:10  Mumbai   6h 40m
#
#            7               8           9               10  \
# 0    Non Stop  2 left at4,373  View Fares  Flight Details
# ...

# %%
Del_MUM_16Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_16Aug.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_16Aug=pd.DataFrame(Del_MUM_16Aug)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_16Aug.xlsx")
df_Del_MUM_16Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_16Aug
# Out:
#            0           1      2          3      4       5       6         7   \
# 0      IndiGo     6E-5023  06:30  New Delhi  08:35  Mumbai  2h 05m  Non Stop
# 1      IndiGo     6E-5318  17:00  New Delhi  19:05  Mumbai  2h 05m  Non Stop
# 2      IndiGo     6E-2112  05:30  New Delhi  07:40  Mumbai  2h 10m  Non Stop
# 3     Vistara      UK-953  20:40  New Delhi  22:50  Mumbai  2h 10m  Non Stop
# 4    Air Asia      I5-753  13:00  New Delhi  14:50  Mumbai  1h 50m  Non Stop
# ..        ...         ...    ...        ...    ...     ...     ...       ...
# 172  SpiceJet  SG-473/951  06:25  New Delhi  13:35  Mumbai  7h 10m    1 Stop
# 173  SpiceJet  SG-473/945  06:25  New Delhi  16:10  Mumbai  9h 45m    1 Stop
# 174   Vistara  UK-817/850  16:05  New Delhi  21:50  Mumbai  5h 45m    1 Stop
# 175   Vistara  UK-819/854  14:15  New Delhi  20:15  Mumbai  6h 00m    1 Stop
# 176  SpiceJet  SG-751/114  11:30  New Delhi  18:10  Mumbai  6h 40m    1 Stop
#
# ...

# %%
Del_MUM_26Aug = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_26Aug.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_26Aug=pd.DataFrame(Del_MUM_26Aug)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_26Aug.xlsx")
df_Del_MUM_26Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_26Aug
# Out:
#            0            1      2          3      4       5        6   \
# 0      IndiGo      6E-5023  06:30  New Delhi  08:35  Mumbai   2h 05m
# 1      IndiGo      6E-6814  07:20  New Delhi  09:25  Mumbai   2h 05m
# 2      IndiGo      6E-5318  17:00  New Delhi  19:05  Mumbai   2h 05m
# 3      IndiGo      6E-2112  05:30  New Delhi  07:40  Mumbai   2h 10m
# 4    SpiceJet      SG-8701  07:20  New Delhi  09:35  Mumbai   2h 15m
# ..        ...          ...    ...        ...    ...     ...      ...
# 160  SpiceJet  SG-8903/398  06:30  New Delhi  14:30  Mumbai   8h 00m
# 161  SpiceJet  SG-8903/168  06:30  New Delhi  19:25  Mumbai  12h 55m
# 162  SpiceJet   SG-473/951  06:25  New Delhi  13:35  Mumbai   7h 10m
# 163  SpiceJet   SG-473/945  06:25  New Delhi  16:10  Mumbai   9h 45m
# 164  SpiceJet   SG-751/114  11:30  New Delhi  18:10  Mumbai   6h 40m
#
#            7               8           9               10  \
# 0    Non Stop  3 left at4,373  View Fares  Flight Details
# ...

# %%
Del_MUM_6Sep = []
for i in driver.find_elements_by_xpath('//div[@class="tuple"]'):
     Del_MUM_6Sep.append(i.text.split('\n'))

#changing to dataframe
df_Del_MUM_6Sep=pd.DataFrame(Del_MUM_6Sep)

#writing in Excel
writer=pd.ExcelWriter("df_Del_MUM_6Sep.xlsx")
df_Del_MUM_6Sep.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_Del_MUM_6Sep
# Out:
#            0            1      2          3      4       5        6   \
# 0     Vistara       UK-975  06:00  New Delhi  08:00  Mumbai   2h 00m
# 1     Vistara       UK-981  21:55  New Delhi  23:55  Mumbai   2h 00m
# 2      IndiGo      6E-5023  06:30  New Delhi  08:35  Mumbai   2h 05m
# 3      IndiGo      6E-6814  07:20  New Delhi  09:25  Mumbai   2h 05m
# 4      IndiGo      6E-5318  17:00  New Delhi  19:05  Mumbai   2h 05m
# ..        ...          ...    ...        ...    ...     ...      ...
# 172  SpiceJet  SG-8903/398  06:30  New Delhi  14:30  Mumbai   8h 00m
# 173  SpiceJet  SG-8903/168  06:30  New Delhi  19:25  Mumbai  12h 55m
# 174  SpiceJet   SG-473/945  06:25  New Delhi  16:10  Mumbai   9h 45m
# 175  SpiceJet   SG-473/951  06:25  New Delhi  13:35  Mumbai   7h 10m
# 176  SpiceJet   SG-751/114  11:30  New Delhi  18:10  Mumbai   6h 40m
#
#            7               8           9               10  \
# 0    Non Stop           4,373    Book Now  Flight Details
# ...

# %%
### https://www.skyscanner.co.in

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220427/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_27apr = []
HYD_BAN_27apr_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_27apr.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_27apr_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_27apr_AIRLINES  = HYD_BAN_27apr_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_27apr=pd.DataFrame(HYD_BAN_27apr)
df_HYD_BAN_27apr_AIRLINES=pd.DataFrame(HYD_BAN_27apr_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_27apr = df_HYD_BAN_27apr.join(df_HYD_BAN_27apr_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_27apr.xlsx")
df_HYD_BAN_27apr.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_27apr
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 5,050.  14:20  HYD   1h 10   Direct
# 1     Flight option 2: Total cost ₹ 4,673.  20:20  HYD   1h 20   Direct
# 2     Flight option 3: Total cost ₹ 5,788.  12:00  HYD   1h 10   Direct
# 3     Flight option 5: Total cost ₹ 5,938.  18:25  HYD   1h 05   Direct
# 4     Flight option 6: Total cost ₹ 5,686.  20:30  HYD   1h 05   Direct
# 5     Flight option 8: Total cost ₹ 5,998.  22:30  HYD   1h 10   Direct
# 6     Flight option 9: Total cost ₹ 7,048.  18:10  HYD   1h 10   Direct
# 7    Flight option 10: Total cost ₹ 7,258.  16:40  HYD   1h 15   Direct
# 8    Flight option 11: Total cost ₹ 5,166.  13:30  HYD   4h 25   1 stop
# 9    Flight option 13: Total cost ₹ 9,157.  13:35  HYD   3h 40   1 stop
# 10  Flight option 14: Total cost ₹ 10,761.  16:20  HYD   3h 35   1 stop
# 11   Flight option 15: Total cost ₹ 9,529.  12:55  HYD   4h 50   1 stop
# ...

# %% [markdown]
# ## Manually select fro diffeernt dates with 10 days differences
#
# ### As there was a issue getting the data and the scapping is detected as scam, So collected the url and extracted the data

# %%
## changed the dates in url and extracted the data

driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220507/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_7May = []
HYD_BAN_7May_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_7May.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_7May_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_7May_AIRLINES  = HYD_BAN_7May_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_7May=pd.DataFrame(HYD_BAN_7May)
df_HYD_BAN_7May_AIRLINES=pd.DataFrame(HYD_BAN_7May_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_7May = df_HYD_BAN_7May.join(df_HYD_BAN_7May_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_7May.xlsx")
df_HYD_BAN_7May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_7May
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,750.  18:25  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,560.  22:30  HYD   1h 10   Direct
# 2      Flight option 3: Total cost ₹ 3,560.  23:40  HYD   1h 10   Direct
# 3      Flight option 5: Total cost ₹ 3,560.  07:00  HYD   1h 15   Direct
# 4      Flight option 6: Total cost ₹ 3,750.  07:30  HYD   1h 15   Direct
# ..                                      ...    ...  ...     ...      ...
# 83  Flight option 103: Total cost ₹ 36,706.  06:10  HYD  16h 20   1 stop
# 84  Flight option 104: Total cost ₹ 53,853.  19:10  HYD  13h 45  2 stops
# 85  Flight option 105: Total cost ₹ 82,084.  21:50  HYD  11h 05   1 stop
# 86  Flight option 106: Total cost ₹ 52,514.  06:10  HYD  17h 45  2 stops
# 87  Flight option 107: Total cost ₹ 36,414.  16:40  HYD  28h 20   1 stop
#
#             5        6              7                            8  \
# ...

# %%
## changed the dates in url and extracted the data

driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220517/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_17May = []
HYD_BAN_17May_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_17May.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_17May_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_17May_AIRLINES  = HYD_BAN_17May_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_17May=pd.DataFrame(HYD_BAN_17May)
df_HYD_BAN_17May_AIRLINES=pd.DataFrame(HYD_BAN_17May_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_17May = df_HYD_BAN_17May.join(df_HYD_BAN_17May_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_17May.xlsx")
df_HYD_BAN_17May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_17May
# Out:
#                                         0_x             1      2       3  \
# 0      Flight option 1: Total cost ₹ 3,944.         18:25    HYD   1h 05
# 1      Flight option 2: Total cost ₹ 4,206.         16:50    HYD   1h 05
# 2      Flight option 3: Total cost ₹ 4,159.         09:30    HYD   1h 05
# 3      Flight option 5: Total cost ₹ 3,967.         14:20    HYD   1h 10
# 4      Flight option 6: Total cost ₹ 3,273.  Alliance Air  20:45     HYD
# ..                                      ...           ...    ...     ...
# 77   Flight option 96: Total cost ₹ 36,680.         06:10    HYD  16h 20
# 78   Flight option 97: Total cost ₹ 34,296.         12:25    HYD     20h
# 79   Flight option 98: Total cost ₹ 53,836.         19:10    HYD  13h 45
# 80   Flight option 99: Total cost ₹ 53,836.         06:00    HYD  16h 30
# 81  Flight option 100: Total cost ₹ 52,488.         06:10    HYD  17h 45
#
#           4          5        6              7                     8  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220527/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_27May = []
HYD_BAN_27May_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_27May.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_27May_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_27May_AIRLINES  = HYD_BAN_27May_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_27May=pd.DataFrame(HYD_BAN_27May)
df_HYD_BAN_27May_AIRLINES=pd.DataFrame(HYD_BAN_27May_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_27May = df_HYD_BAN_27May.join(df_HYD_BAN_27May_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_27May.xlsx")
df_HYD_BAN_27May.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_27May
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,637.  09:30  HYD   1h 05   Direct
# 2      Flight option 3: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 3      Flight option 5: Total cost ₹ 3,623.  12:00  HYD   1h 10   Direct
# 4      Flight option 6: Total cost ₹ 3,623.  08:15  HYD   1h 15   Direct
# ..                                      ...    ...  ...     ...      ...
# 80  Flight option 100: Total cost ₹ 34,412.  06:15  HYD  13h 10   1 stop
# 81  Flight option 101: Total cost ₹ 35,564.  06:10  HYD  16h 20   1 stop
# 82  Flight option 102: Total cost ₹ 51,590.  19:10  HYD  13h 45  2 stops
# 83  Flight option 103: Total cost ₹ 36,334.  00:15  HYD  23h 25   1 stop
# 84  Flight option 104: Total cost ₹ 50,955.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                            8  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220607/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_7June = []
HYD_BAN_7June_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_7June.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_7June_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_7June_AIRLINES  = HYD_BAN_7June_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_7June=pd.DataFrame(HYD_BAN_7June)
df_HYD_BAN_7June_AIRLINES=pd.DataFrame(HYD_BAN_7June_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_7June = df_HYD_BAN_7June.join(df_HYD_BAN_7June_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_7June.xlsx")
df_HYD_BAN_7June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_7June
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,623.  09:30  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,623.  20:30  HYD   1h 05   Direct
# 3     Flight option 5: Total cost ₹ 3,623.  18:10  HYD   1h 10   Direct
# 4     Flight option 6: Total cost ₹ 3,623.  12:00  HYD   1h 10   Direct
# ..                                     ...    ...  ...     ...      ...
# 75  Flight option 94: Total cost ₹ 12,653.  16:10  HYD  32h 10  2 stops
# 76  Flight option 95: Total cost ₹ 34,412.  06:15  HYD  13h 10   1 stop
# 77  Flight option 96: Total cost ₹ 35,564.  06:10  HYD  16h 20   1 stop
# 78  Flight option 97: Total cost ₹ 51,590.  19:10  HYD  13h 45  2 stops
# 79  Flight option 98: Total cost ₹ 50,955.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220617/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_17June = []
HYD_BAN_17June_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_17June.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_17June_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_17June_AIRLINES  = HYD_BAN_17June_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_17June=pd.DataFrame(HYD_BAN_17June)
df_HYD_BAN_17June_AIRLINES=pd.DataFrame(HYD_BAN_17June_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_17June = df_HYD_BAN_17June.join(df_HYD_BAN_17June_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_17June.xlsx")
df_HYD_BAN_17June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_17June
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,837.  09:30  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 3     Flight option 5: Total cost ₹ 3,837.  20:30  HYD   1h 05   Direct
# 4     Flight option 6: Total cost ₹ 3,744.  14:20  HYD   1h 10   Direct
# ..                                     ...    ...  ...     ...      ...
# 74  Flight option 92: Total cost ₹ 35,559.  06:10  HYD  16h 20   1 stop
# 75  Flight option 93: Total cost ₹ 29,937.  00:15  HYD  23h 25   1 stop
# 76  Flight option 94: Total cost ₹ 51,590.  19:10  HYD  13h 45  2 stops
# 77  Flight option 95: Total cost ₹ 51,590.  06:00  HYD  16h 30  2 stops
# 78  Flight option 96: Total cost ₹ 50,955.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220627/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_27June = []
HYD_BAN_27June_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_27June.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_27June_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_27June_AIRLINES  = HYD_BAN_27June_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_27June=pd.DataFrame(HYD_BAN_27June)
df_HYD_BAN_27June_AIRLINES=pd.DataFrame(HYD_BAN_27June_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_27June = df_HYD_BAN_27June.join(df_HYD_BAN_27June_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_27June.xlsx")
df_HYD_BAN_27June.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_27June
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,230.  18:25  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,352.  21:10  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,352.  14:20  HYD   1h 10   Direct
# 3     Flight option 5: Total cost ₹ 3,230.  07:30  HYD   1h 15   Direct
# 4     Flight option 6: Total cost ₹ 3,681.  12:00  HYD   1h 15   Direct
# ..                                     ...    ...  ...     ...      ...
# 71  Flight option 89: Total cost ₹ 21,998.  21:20  HYD  22h 50   1 stop
# 72  Flight option 90: Total cost ₹ 35,555.  06:10  HYD  16h 20   1 stop
# 73  Flight option 91: Total cost ₹ 51,587.  19:10  HYD  13h 45  2 stops
# 74  Flight option 92: Total cost ₹ 51,587.  06:00  HYD  16h 30  2 stops
# 75  Flight option 93: Total cost ₹ 50,953.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(3)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220707/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_7July = []
HYD_BAN_7July_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_7July.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_7July_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_7July_AIRLINES  = HYD_BAN_7July_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_7July=pd.DataFrame(HYD_BAN_7July)
df_HYD_BAN_7July_AIRLINES=pd.DataFrame(HYD_BAN_7July_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_7July = df_HYD_BAN_7July.join(df_HYD_BAN_7July_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_7July.xlsx")
df_HYD_BAN_7July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_7July
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,230.  18:25  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,200.  06:00  HYD   1h 05   Direct
# 2      Flight option 3: Total cost ₹ 3,230.  07:30  HYD   1h 15   Direct
# 3      Flight option 5: Total cost ₹ 3,352.  14:20  HYD   1h 10   Direct
# 4      Flight option 6: Total cost ₹ 3,623.  09:30  HYD   1h 05   Direct
# ..                                      ...    ...  ...     ...      ...
# 80  Flight option 100: Total cost ₹ 34,677.  06:15  HYD  13h 10   1 stop
# 81  Flight option 101: Total cost ₹ 35,457.  06:10  HYD  16h 20   1 stop
# 82  Flight option 102: Total cost ₹ 51,581.  19:10  HYD  13h 45  2 stops
# 83  Flight option 103: Total cost ₹ 51,581.  06:00  HYD  16h 30  2 stops
# 84  Flight option 104: Total cost ₹ 50,946.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(10)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220717/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_17July = []
HYD_BAN_17July_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_17July.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_17July_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_17July_AIRLINES  = HYD_BAN_17July_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_17July=pd.DataFrame(HYD_BAN_17July)
df_HYD_BAN_17July_AIRLINES=pd.DataFrame(HYD_BAN_17July_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_17July = df_HYD_BAN_17July.join(df_HYD_BAN_17July_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_17July.xlsx")
df_HYD_BAN_17July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_17July
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,200.  06:00  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,230.  18:25  HYD   1h 05   Direct
# 2      Flight option 3: Total cost ₹ 3,351.  23:40  HYD   1h 10   Direct
# 3      Flight option 5: Total cost ₹ 3,351.  22:30  HYD   1h 10   Direct
# 4      Flight option 6: Total cost ₹ 3,623.  09:30  HYD   1h 05   Direct
# ..                                      ...    ...  ...     ...      ...
# 77   Flight option 96: Total cost ₹ 17,278.  20:30  HYD  25h 20  2 stops
# 78   Flight option 97: Total cost ₹ 34,675.  06:15  HYD  13h 10   1 stop
# 79   Flight option 98: Total cost ₹ 35,456.  06:10  HYD  16h 20   1 stop
# 80   Flight option 99: Total cost ₹ 51,576.  19:10  HYD  13h 45  2 stops
# 81  Flight option 100: Total cost ₹ 51,580.  06:00  HYD  16h 30  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(2)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220727/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_27July = []
HYD_BAN_27July_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_27July.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_27July_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_27July_AIRLINES  = HYD_BAN_27July_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_27July=pd.DataFrame(HYD_BAN_27July)
df_HYD_BAN_27July_AIRLINES=pd.DataFrame(HYD_BAN_27July_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_27July = df_HYD_BAN_27July.join(df_HYD_BAN_27July_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_27July.xlsx")
df_HYD_BAN_27July.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_27July
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,532.  06:00  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,623.  09:30  HYD   1h 05   Direct
# 3     Flight option 5: Total cost ₹ 3,623.  20:30  HYD   1h 05   Direct
# 4     Flight option 6: Total cost ₹ 3,623.  12:00  HYD   1h 10   Direct
# ..                                     ...    ...  ...     ...      ...
# 74  Flight option 92: Total cost ₹ 34,573.  06:15  HYD  13h 10   1 stop
# 75  Flight option 93: Total cost ₹ 35,443.  06:10  HYD  16h 20   1 stop
# 76  Flight option 94: Total cost ₹ 51,567.  19:10  HYD  13h 45  2 stops
# 77  Flight option 95: Total cost ₹ 51,567.  06:00  HYD  16h 30  2 stops
# 78  Flight option 96: Total cost ₹ 50,932.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                            8  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(2)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220807/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_7Aug = []
HYD_BAN_7Aug_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_7Aug.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_7Aug_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_7Aug_AIRLINES  = HYD_BAN_7Aug_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_7Aug=pd.DataFrame(HYD_BAN_7Aug)
df_HYD_BAN_7Aug_AIRLINES=pd.DataFrame(HYD_BAN_7Aug_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_7Aug = df_HYD_BAN_7Aug.join(df_HYD_BAN_7Aug_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_7Aug.xlsx")
df_HYD_BAN_7Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_7Aug
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,350.  06:00  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 2      Flight option 3: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 3      Flight option 5: Total cost ₹ 3,837.  09:30  HYD   1h 05   Direct
# 4      Flight option 6: Total cost ₹ 3,837.  20:30  HYD   1h 05   Direct
# ..                                      ...    ...  ...     ...      ...
# 78   Flight option 97: Total cost ₹ 35,425.  06:15  HYD  13h 10   1 stop
# 79   Flight option 98: Total cost ₹ 36,258.  06:10  HYD  16h 20   1 stop
# 80   Flight option 99: Total cost ₹ 55,033.  19:10  HYD  13h 45  2 stops
# 81  Flight option 100: Total cost ₹ 51,474.  06:10  HYD  17h 15  2 stops
# 82  Flight option 101: Total cost ₹ 55,033.  06:00  HYD  16h 30  2 stops
#
#             5        6              7                            8         9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(2)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220817/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_17Aug = []
HYD_BAN_17Aug_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_17Aug.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_17Aug_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_17Aug_AIRLINES  = HYD_BAN_17Aug_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_17Aug=pd.DataFrame(HYD_BAN_17Aug)
df_HYD_BAN_17Aug_AIRLINES=pd.DataFrame(HYD_BAN_17Aug_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_17Aug = df_HYD_BAN_17Aug.join(df_HYD_BAN_17Aug_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_17Aug.xlsx")
df_HYD_BAN_17Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_17Aug
# Out:
#                                         0_x      1    2       3        4  \
# 0      Flight option 1: Total cost ₹ 3,350.  06:00  HYD   1h 05   Direct
# 1      Flight option 2: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 2      Flight option 3: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 3      Flight option 5: Total cost ₹ 3,837.  09:30  HYD   1h 05   Direct
# 4      Flight option 6: Total cost ₹ 3,681.  12:00  HYD   1h 15   Direct
# ..                                      ...    ...  ...     ...      ...
# 78   Flight option 97: Total cost ₹ 34,571.  06:15  HYD  13h 10   1 stop
# 79   Flight option 98: Total cost ₹ 35,441.  06:10  HYD  16h 20   1 stop
# 80   Flight option 99: Total cost ₹ 53,597.  19:10  HYD  13h 45  2 stops
# 81  Flight option 100: Total cost ₹ 50,931.  06:10  HYD  17h 15  2 stops
# 82  Flight option 101: Total cost ₹ 53,597.  06:00  HYD  16h 30  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(2)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220827/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_27Aug = []
HYD_BAN_27Aug_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_27Aug.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_27Aug_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_27Aug_AIRLINES  = HYD_BAN_27Aug_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_27Aug=pd.DataFrame(HYD_BAN_27Aug)
df_HYD_BAN_27Aug_AIRLINES=pd.DataFrame(HYD_BAN_27Aug_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_27Aug = df_HYD_BAN_27Aug.join(df_HYD_BAN_27Aug_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_27Aug.xlsx")
df_HYD_BAN_27Aug.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_27Aug
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,350.  06:00  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,837.  09:30  HYD   1h 05   Direct
# 3     Flight option 5: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 4     Flight option 6: Total cost ₹ 3,837.  20:30  HYD   1h 05   Direct
# ..                                     ...    ...  ...     ...      ...
# 78  Flight option 80: Total cost ₹ 15,488.  20:30  HYD  19h 50  2 stops
# 79  Flight option 81: Total cost ₹ 13,183.  20:30  HYD  25h 20  2 stops
# 80  Flight option 82: Total cost ₹ 35,437.  06:10  HYD  16h 20   1 stop
# 81  Flight option 83: Total cost ₹ 55,033.  19:10  HYD  13h 45  2 stops
# 82  Flight option 84: Total cost ₹ 50,927.  06:10  HYD  17h 15  2 stops
#
#             5        6              7                     8             9  \
# ...

# %%
driver=webdriver.Chrome(r'C:\Users\surendar.reddy\Documents\data Science projet_Data traine\chromedriver.exe')
time.sleep(2)
url ="https://www.skyscanner.co.in/transport/flights/hyd/blr/220907/?adultsv2=1&cabinclass=economy&childrenv2=&inboundaltsenabled=false&outboundaltsenabled=false&preferdirects=false&priceSourceId=&priceTrace=&qp_prevCurrency=INR&qp_prevPrice=OneWayNone&qp_prevProvider=ins_month&rtn=0"
driver.get(url)

# %%
HYD_BAN_7Sep = []
HYD_BAN_7Sep_AIRLINES = []
for i in driver.find_elements_by_xpath('//div[@class="FlightsTicket_container__NWJkY"]'):
     HYD_BAN_7Sep.append(i.text.split('\n'))       
for i in driver.find_elements_by_xpath("//div[@class='BpkImage_bpk-image__NzYwO BpkImage_bpk-image--no-background__OTRiM']//img") :
     HYD_BAN_7Sep_AIRLINES.append(i.get_attribute('alt'))

# slicing odd
HYD_BAN_7Sep_AIRLINES  = HYD_BAN_7Sep_AIRLINES[::2]

#changing to dataframe
df_HYD_BAN_7Sep=pd.DataFrame(HYD_BAN_7Sep)
df_HYD_BAN_7Sep_AIRLINES=pd.DataFrame(HYD_BAN_7Sep_AIRLINES)

#join the 2 data Frame
df_HYD_BAN_7Sep = df_HYD_BAN_7Sep.join(df_HYD_BAN_7Sep_AIRLINES,how = 'right', lsuffix='_x')
#merged = df_train_csv.join(df_train_fly, how = 'right', lsuffix='_x')

#writing in Excel
writer=pd.ExcelWriter("df_HYD_BAN_7Sep.xlsx")
df_HYD_BAN_7Sep.to_excel(writer,"sheet", header=True, index= False)
writer.save()

#display the dataframe
df_HYD_BAN_7Sep
# Out:
#                                        0_x      1    2       3        4  \
# 0     Flight option 1: Total cost ₹ 3,551.  18:25  HYD   1h 05   Direct
# 1     Flight option 2: Total cost ₹ 3,532.  06:00  HYD   1h 05   Direct
# 2     Flight option 3: Total cost ₹ 3,837.  09:30  HYD   1h 05   Direct
# 3     Flight option 5: Total cost ₹ 3,551.  07:30  HYD   1h 15   Direct
# 4     Flight option 6: Total cost ₹ 3,681.  12:00  HYD   1h 15   Direct
# ..                                     ...    ...  ...     ...      ...
# 72  Flight option 90: Total cost ₹ 35,425.  06:15  HYD  13h 10   1 stop
# 73  Flight option 91: Total cost ₹ 36,258.  06:10  HYD  16h 20   1 stop
# 74  Flight option 92: Total cost ₹ 55,033.  19:10  HYD  13h 45  2 stops
# 75  Flight option 93: Total cost ₹ 51,474.  06:10  HYD  17h 15  2 stops
# 76  Flight option 94: Total cost ₹ 55,033.  06:00  HYD  16h 30  2 stops
#
#             5        6              7                            8  \
# ...
